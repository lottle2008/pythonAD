# %% [markdown]
# https://curlconverter.com/

# %%
import subprocess
import json


def call_node_js(encrypted_text):
    # 使用 subprocess 调用 Node.js 并运行 decrypt.js 文件
    result = subprocess.run(
        ['node', '-e', f'''
        const decryptAndDecompress = require('./1.js');
        const result = decryptAndDecompress("{encrypted_text}");
        console.log(JSON.stringify({{ "result": result }}));
        '''],
        capture_output=True, text=True
    )

    # 输出 Node.js 的 stdout 和 stderr 以便调试
    print("Node.js stdout:", result.stdout)
    print("Node.js stderr:", result.stderr)

    # 尝试解析 JSON 输出
    try:
        output = json.loads(result.stdout)
        return output.get("result")
    except json.JSONDecodeError as e:
        print("Error decoding JSON:", e)
        return None
import requests

headers = {
    'accept': 'application/json',
    'accept-language': 'zh-CN,zh;q=0.9',
    'cache-control': 'no-cache',
    'cache-ts': '1727006913694',
    'encryption': 'true',
    'language': 'en',
    'origin': 'https://www.coinglass.com',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://www.coinglass.com/',
    'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
}

params = {
    'symbol': 'SOL',
}

response = requests.get('https://capi.coinglass.com/api/openInterest/ex/info', params=params, headers=headers)
# print(response.json())
# data=response.json().get('data')
# print(data)
encrypted_text = "..."

decrypted_text = call_node_js(encrypted_text)
print("Decrypted text:", decrypted_text)
# Out:
# Node.js stdout: Encrypted Data: ...
# Decrypted Hex: ...
# ...
